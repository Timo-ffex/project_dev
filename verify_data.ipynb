# %%
import pandas as pd

path = '/Users/dit/Documents/code/Learning/end-to-end-DE-project/yellow_tripdata_2020-12.parquet'
path = '/Users/dit/Documents/code/Learning/end-to-end-DE-project/green_tripdata_2021-01.parquet'
path = '/Users/dit/Documents/code/Learning/end-to-end-DE-project/fhv_tripdata_2021-02.parquet'
df = pd.read_parquet(path)
df.head()
# Out:
#   dispatching_base_num     pickup_datetime    dropOff_datetime  PUlocationID  \
# 0               B00013 2021-02-01 00:01:00 2021-02-01 01:33:00           NaN
# 1      B00021          2021-02-01 00:55:40 2021-02-01 01:06:20         173.0
# 2      B00021          2021-02-01 00:14:03 2021-02-01 00:28:37         173.0
# 3      B00021          2021-02-01 00:27:48 2021-02-01 00:35:45          82.0
# 4               B00037 2021-02-01 00:12:50 2021-02-01 00:26:38           NaN
#
#    DOlocationID SR_Flag Affiliated_base_number
# 0           NaN    None                 B00014
# 1          82.0    None        B00021
# 2          56.0    None        B00021
# 3         129.0    None        B00021
# 4         225.0    None                 B00037

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037692 entries, 0 to 1037691
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   dispatching_base_num    1037692 non-null  object
#  1   pickup_datetime         1037692 non-null  datetime64[ns]
#  2   dropOff_datetime        1037692 non-null  datetime64[ns]
#  3   PUlocationID            153001 non-null   float64
#  4   DOlocationID            885340 non-null   float64
#  5   SR_Flag                 0 non-null        object
#  6   Affiliated_base_number  1037692 non-null  object
# dtypes: datetime64[ns](2), float64(2), object(3)
# memory usage: 55.4+ MB

# %%
df['dispatching_base_num'].value_counts()
# Out:
# B00856     35077
# B01312     33089
# B01145     31114
# B02794     30397
# B03016     29794
#            ...
# B01944         2
# B01928         2
# B02811         2
# B02273         1
# B02004         1
# Name: dispatching_base_num, Length: 496, dtype: int64

# %%
df.sort_values(by=['tpep_pickup_datetime'], ascending=False).head(10)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1015665         2  2021-06-10 10:10:48   2021-06-10 10:41:42              1.0
# 1015664         2  2021-05-20 02:40:50   2021-05-20 02:47:10              1.0
# 1011126         2  2021-05-20 02:07:54   2021-05-20 02:13:51              1.0
# 1011125         2  2021-04-28 18:43:30   2021-04-29 02:02:52              1.0
# 1011124         2  2021-04-28 18:28:11   2021-04-28 18:40:24              1.0
# 1002344         2  2021-04-07 10:11:40   2021-04-07 10:21:34              1.0
# 1316266         2  2021-02-10 20:33:42   2021-02-10 20:38:45              1.0
# 1316265         2  2021-02-10 19:55:55   2021-02-10 20:04:09              1.0
# 994942          2  2021-02-02 08:54:06   2021-02-02 16:08:32              1.0
# 994941          2  2021-02-02 08:19:02   2021-02-02 08:29:21              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# ...

# %%
61-43
# Out:
# 18

# %%
60-43
# Out:
# 17
